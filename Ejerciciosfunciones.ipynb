# %%
#Desarrollo de la función 1

def Ult_Dig(Num):
  UltDig = 0
  UltDig = Num%100
  return(UltDig)

#Llamado de la función 

valor = int(input("Digite Numero:..."))
print("El último digito es:...", Ult_Dig(valor))

# %%
#Desarrollo de la función 2

def Ult_Dig(Num)
  UltDig = 0
  UltDig = Num%100
  return(UltDig)

#Llamado de la función 

valor = int(input("Digite Numero:..."))
print("El último digito es:...",Ult_Dig(valor))

# %%
  while n != 0:def countDigit(n):
  count = 0
    n //= 10
    count += 1
  return count

# Driver code
n = int(input("Digite Número:... "))
print("Number of digits : % d" % (countDigit(n)))

# %%
def cant_DigPares(Num)
  cant_DigPares = 0
  cant_DigPares > 0
    cant_DigPares Num%10
  if
