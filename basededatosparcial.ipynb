# %%
# %config IPCompleter.greedy=True
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# ### cargar la base de datos

# %%
from google.colab import files

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel("//content/drive/MyDrive/excel/data_ventas_video_juegos.xlsx")
df.shape
# Out:
# (29999, 7)

# %%
#Tamaño de los datos
print('\nEl tamaño de los datos por filas y columnas',df.shape)
# Out:
# El tamaño de los datos por filas y columnas (29999, 7)

# %%
df.dtypes
print('\nlos datos son de tipo:\n',df.dtypes)
# Out:
# los datos son de tipo:
#  Editorial          object
# Genero             object
# Plataforma         object
# Nombre             object
# Plataforma.1       object
# Región             object
# Venta Millones    float64
# dtype: object

# %%
df.head(5)
# Out:
#          Editorial     Genero Plataforma  \
# 0  10TACLE Studios  Adventure        PS2
# 1  10TACLE Studios  Adventure        PS2
# 2  10TACLE Studios  Adventure        PS2
# 3  10TACLE Studios  Adventure        PS2
# 4  10TACLE Studios     Puzzle         DS
#
#                                    Nombre Plataforma.1         Región  \
# 0  Pirates: Legend of the Black Buccaneer          PS2         Europa
# 1  Pirates: Legend of the Black Buccaneer          PS2          Japón
# 2  Pirates: Legend of the Black Buccaneer          PS2  Norte América
# 3  Pirates: Legend of the Black Buccaneer          PS2          Otros
# 4                    Boulder Dash: Rocks!           DS         Europa
#
#    Venta Millones
# 0            0.01
# 1            0.00
# 2            0.01
# 3            0.00
# 4            0.03

# %%
#Enviando Parametro y Retornando valor.
def primer_dig(num):
  if num<=99:
    num//= 10
  elif num<=999:
    num//=100
  elif num<=9999:
    num//=1000
  elif num<=99999:
    num//=10000
  elif num<=999999:
    num//=100000
  elif num<=9999999:
    num//=1000000

  return(num)

num=int(input("Ingrese el digito: "))
print("El primer digito es: ", primer_dig(num))

# Sin Recibir Parametro y Retornar valor.
def primer_dig_sin_recibir_parametro():
  num=int(input("Ingrese el digito: "))
  if num<=99:
    num//= 10
  elif num<=999:
    num//=100
  elif num<=9999:
    num//=1000
  elif num<=99999:
    num//=10000
  elif num<=999999:
    num//=100000
  elif num<=9999999:
    num//=1000000

  primer_dig_sin_recibir_parametro()
print("El primer digito es: ", primer_dig_sin_recibir_parametro())

# Sin Recibir Parametro y Sin Retornar valor.
def primer_dig_sin_recibir_parametro_sin_retornar_valor():
  num=int(input("Ingrese el digito: "))
  if num<=99:
    num//= 10
  elif num<=999:
    num//=100
  elif num<=9999:
    num//=1000
  elif num<=99999:
    num//=10000
  elif num<=999999:
    num//=100000
  elif num<=9999999:
    num//=1000000
  print("El primer digito es: ", num)


primer_dig_sin_recibir_parametro_sin_retornar_valor()


# Enviando Parametro y Sin Retornar valor.
def imprimir_primer_dig(num):
  if num<=99:
    num//= 10
  elif num<=999:
    num//=100
  elif num<=9999:
    num//=1000
  elif num<=99999:
    num//=10000
  elif num<=999999:
    num//=100000
  elif num<=9999999:
    num//=1000000
  
  print("El primer digito es: ", primer_dig(num))
  


num = int(input("Ingrese el digito: "))
imprimir_primer_dig(num)
# Out:
# Ingrese el digito: 7
# El primer digito es:  0
# Ingrese el digito: 8
# Ingrese el digito: 7
# Ingrese el digito: 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-bc2704bf46d0> in <module>
#      36
#      37   primer_dig_sin_recibir_parametro()
# ---> 38 print("El primer digito es: ", primer_dig_sin_recibir_parametro())
#      39
#      40 # Sin Recibir Parametro y Sin Retornar valor.
#
# <ipython-input-5-bc2704bf46d0> in primer_dig_sin_recibir_parametro()
#      35     num//=1000000
#      36
# ---> 37   primer_dig_sin_recibir_parametro()
#      38 print("El primer digito es: ", primer_dig_sin_recibir_parametro())
#      39
#
# <ipython-input-5-bc2704bf46d0> in primer_dig_sin_recibir_parametro()
#      35     num//=1000000
#      36
# ---> 37   primer_dig_sin_recibir_parametro()
#      38 print("El primer digito es: ", primer_dig_sin_recibir_parametro())
# ...
