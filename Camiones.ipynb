# %%
i = 1
j = 0

for i in range(20): #CAPACIDAD DE 20 CAMIONES
  print('Se introducira la capacidad del camion #', i)
  capacid= float(input('Introducir capacidad del camion a llenar:'))
  carg = 0
  pes_sac = 0
  while (carg+pes_sac)<= capacid:
    if pes_sac<0:
      print('Cargar la saca #', j) 
    carg = carg+pes_sac
    j = j +1
    print('Ingresara el peso de la saca #', j)
    pes_sac = float(input('Ingresar el peso de la saca que se va a cargar:'))
    
    carg_tot = carg+pes_sac

  if i<20:
    print('No cargar el camion #', i, 'Cargue el camion #', i+1)

print('No cargar la saca. Despache camion', i-1)
print('Fin de la carga del día')
# Out:
# Se introducira la capacidad del camion # 0
# Introducir capacidad del camion a llenar:50
# Ingresara el peso de la saca # 1
# Ingresar el peso de la saca que se va a cargar:35
# Ingresara el peso de la saca # 2
# Ingresar el peso de la saca que se va a cargar:40
# No cargar el camion # 0 Cargue el camion # 1
# Se introducira la capacidad del camion # 1
# Introducir capacidad del camion a llenar:40
# Ingresara el peso de la saca # 3
# Ingresar el peso de la saca que se va a cargar:60
# No cargar el camion # 1 Cargue el camion # 2
# Se introducira la capacidad del camion # 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-18a7b5226a0b> in <module>
#       4 for i in range(20): #CAPACIDAD DE 20 CAMIONES
#       5   print('Se introducira la capacidad del camion #', i)
# ----> 6   capacid= float(input('Introducir capacidad del camion a llenar:'))
# ...
