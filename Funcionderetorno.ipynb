# %%
#Ejemplo función que recibe y retorna
def sumatoria(n,e):
  s=0
  for i in range(n):
    s=s+pow(i,e)
  return s
val=int(input("Digite el valor "))
exp=int(input("Digite el exponente "))
resSum = sumatoria(val,exp)
print("La sumatoria es: ",resSum)
# Out:
# Digite el valor 8
# Digite el exponente 2
# La sumatoria es:  140
