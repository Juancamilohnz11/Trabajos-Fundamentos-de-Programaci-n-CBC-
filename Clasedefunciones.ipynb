# %%
def mostrar_mensajes():
  print("***************************************************")
  print("FUNCION QUE NO RECIBE PARAMETRO Y NO RETORNA VALOR")
  print("LINEA DOS DEL MENSAJE")
  print("**************************************************")

mostrar_mensajes()

# %%
def mostrar_mensajes(mensajes):
  print("***************************************************")
  print(mensaje)
  print("***************************************************")

# %%
#Ejemplo de función que recibe y no retorna

def sumatoria (n)
  s=0
  for i in range(n)
  s=s+pow(i,2)
  print("La sumatoria es: ",s)

sumatoria(s)

# %%
#Ejemplo de función que recibe y retorna


def sumatoria (n):
  s=0
  for i in range (n):
    s=s+pow(i,2)
  return s
