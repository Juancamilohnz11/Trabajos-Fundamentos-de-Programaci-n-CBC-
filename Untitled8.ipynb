# %%
def Ult_dig(Entero:Num)
  Ultimo_digito= Num %10
  return(Ultimo_digito)

Num=int(input("Ingrese un numero: "))
Entero=0
print("El último digito del numero es: ",Ult_dig(Entero:Num))
# Out:
#   File "<ipython-input-4-4adab7226d6c>", line 1
#     def Ult_dig(Entero,Num)
#                            ^
# SyntaxError: invalid syntax
