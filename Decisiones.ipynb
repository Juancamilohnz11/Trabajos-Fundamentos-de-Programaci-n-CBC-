# %% [markdown]
# """
# Descripción: Leer de un estudiante su nombre y las notas de los 3 parciales,
# se necesita calcular su nota definitiva sabiendo que es el promedio de los parciales, ademas imprimir un concepto de aprobó o reprobó
#
# Autor: Grupo FP_dia
# Fecha: 1_09_2022
# versión 1.0
# """

# %%
# Declaración de variables
Var_ent_cad_nomnbreEstudinte = "NN"
Var_ent_float_notaPP = 0.0
Var_ent_float_notaSP = 0.0
Var_ent_float_notaTP = 0.0
Var_proSal_float_notaDefPro = 0.0
Var_proSal_float_notaDefPor = 0.0
Var_proSal_cad_concepto = ""
Var_pro_int_ConCicFor = 0

# %%
for var_pro_int_conCicFor in range(10):
  print("Digite datos para el estudiante"),var_pro_int

# %%
# Lectura de datos - captura por teclado
var_ent_cad_nombreEstudiante = input("Digite nombre del Estudiante:...")
var_ent_float_notaPP = float(input("Digite la primer nota del parcial:..."))
var_ent_float_notaSP = float(input("Digite la segunda nota del parcial:..."))
var_ent_float_notaTP = float(input("Digite la tercer nota del parcial:..."))

# %%
# Procesos
var_proSal_float_notaDef = (var_ent_float_notaPP+var_ent_float_notaSP+var_ent_float_notaTP)/3
# Calculo de nota definitiva por porcentaje
var_proSal_float_notaDef = (var_ent_float_notaPP*0.25+var_ent_float_notaSP*0.25+var_ent_float_notaTP*0.5)/3
# calculo del concepto si aprueba
if (var_proSal_float_notaDefPro>=3.0):
  var_proSal_cad_concepto = "Aprobó - Te promueves al siguiente curso"

# calculo del concepto si reprueba
if (var_proSal_float_notaDefPro<=3.0)
  var_proSal_cad_concepto = "Reprobó - Sigue intentando"

# %%
# Salidas - O impresiones por pantalla
print("Nombre del estuiante:...",var_ent_cad_nombreEstudiante)
print("Definitiva por promedio",var_proSal_float_notaDefPro)
print("Concepto",var_proSal_cad_concepto )
print("Definitiva por porcentaje",var_proSal_float_notaDefPor)
