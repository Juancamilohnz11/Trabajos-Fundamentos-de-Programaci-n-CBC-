# %%
#Programa:leer las notas de 35 estudiantes y calcular el promedio
#Autor: Grup FP-dia 2022_2
#version: 1.0
#fecha: 08_09_2022

# %%
#Declaración e inicialización de variables
const_int_can_estv = 3 #
const_int_can_mat = 3 #Constante que almacena el número de estudiante 
var_ent_string_nombreEstudiante = "" 
var_ent_float__notaDef = 0.0
var_pro_float_sumDefGru = 0.0
Var_proSal_float_promGru = 0.0
var_pro_int_conCic = 0 #Variable que controla las repeticiones del ciclo
var_proSal_float_NotMay = 0.0 # Variable para identificar la mayor nota
var_proSal_int_canEstGan = 0

# %%
#Lectura o captura de datos
#Ciclo que repite por número de asignatura
for var_pro_int_conCic in range(const_int_can_estv):
 # Lectura del nombre del estudiante 
 var_ent_string_nombreEstudiante = input("Digite el nombre del estudiante")
 # Lectura de la nota del estudiante 
 var_ent_float_notaDef = float(input("Digite Nota Definitiva: "))
 # Definir el concepto de la nota 6 o más aprueba, de lo contrario reprueba
 If var_ent_float_notaDef>=6.0:
    print("Usted aprobó la asignatura")
 Else:
    print("Usted no aprobó la asignatura")
#Fin del concepto 
   if(var_ent_float_notaDef>var_proSal_float_notMay):
   var_proSal_float_NotMay = var_ent_float_notaDef
# Calcular cuántos estudiantes ganaron la asignatura
    if(  
var_proSal_float_notMay
 # Acumular la suma de las notas 
 var_pro_float_sumDefGru = var_pro_float_sumDefGru+ var_ent_float_notaDef
 # punto de control para verificar la acumulación de las notas
 #print("Lleva acumulado:,var_pro_float_sumDefGru)
# Fin del ciclo

# Cálculo del promedio del grupo 
Var_proSal_float_promGru = var_pro_float_sumDefGru/const_int_can_estv
print("El promedio del grupo de " +var_ent_string_nombreMateria + "es :" +str(var_proSal_float_promGru)
    #Calculo nota mayor
print("Hasta el momento la nota mayor es:",var_proSal_float_notMay)
#punto de control
print("Llevamos ganados:",var_proSal)
#Calculo de la nota
# Out:
#   File "<ipython-input-15-c7b4e2dae60e>", line 8
#     If var_ent_float_notaDef>=6.0:
#                            ^
# SyntaxError: invalid syntax
