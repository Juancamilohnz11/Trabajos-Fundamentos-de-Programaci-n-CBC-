# %%
#Declaración de variables
angulo=0.0
var_angulo=''

# %%
angulo=float(input('Escriba el ángulo del:...'))

# %%
if(angulo<90):
  var_angulo = 'Es un ángulo agudo' 
if(angulo>90):
  var_angulo = 'Es un ángulo obtuso' 
if(angulo==90) 
  var_angulo = 'Es un ángulo recto'

# %%
print('Angulo:...',var_angulo)
