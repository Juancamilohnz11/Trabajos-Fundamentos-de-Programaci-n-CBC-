# %%
#Definir variables

acuaSalario=0
acuImp=0

cant_emp=int (input("Ingrese la cantidad de empleados:...")

For i in range(cant_emp):
  Nombre= input("Ingrese el nombre del empleado:... ")) 
  Tarifa= float(input("Ingrese el salario básico por hora:...")) 
  Horas= int(input("Ingrese las horas trabajadas durante la semana:...")) )
# Out:
#   File "<ipython-input-2-fac75733ddb8>", line 3
#     Nombre=input("Ingrese el nombre del empleado:... "))
#                                                        ^
# SyntaxError: invalid syntax

# %%
#Verificar si horas trabajas es <= 35 y poner condicionales
If Horas<=35:
  Salario=Horas*Tarifa
  print("El salario semanal es",Salario) 
Else;
  Salario=35*Tarifa+(Horas - 35)*Tarifa*1.5
  print("El salario semanal con recargo es",Salario)
# Out:
#   File "<ipython-input-3-510e7d13b5ea>", line 2
#     If Horas<=35:
#            ^
# SyntaxError: invalid syntax

# %%
#Calculo de impuesto

If salario<=2000:
  Impuestos=0
  print("El total de impuestos es",Impuestos) 
elif Salario<=2200:
  Impuestos=(Salario-2000)*0.20
  print("El total de impuesto es",Impuestos) 
elif salario>2200:
  Impuestos=(Salario-2200)*0.30+(220*0.20)
  print("El total de impuestos es",Impuestos)
  acuImp=acuImp+Impuestos

# %%
#Calculo del salario neto

Salario_neto=Salario-Impuestos
print("El salario semanal es de:...",Salario_neto)
acuSalario=acuSalario+Salario_neto

#Fin del ciclo
print("Los impuestos a pagar son:...",acuImp) 
print("El valor total de la nómina:...acuSalario) 
#Acumulador de impuesto= impuestos+acumulador de impuestos
#Acumulador a pagar=acumulador neto a pagar+salario neto
