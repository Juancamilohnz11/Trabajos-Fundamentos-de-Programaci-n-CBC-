# %%
class coche():
  # Atributos
    ruedas=4
    cilindraje = 1000
    combustible= "Gasolina"
    puerta = 3

# metodo
    def desplazamiento(self):
        print("El coche se está desplazando sobre 4 ruedas")

# Programa principal

# Generar una instancia de la clase
# Instanciar un objeto
# Declarar un objeto 
miVehiculo=coche()
obj_micarrito = coche()
# Acceso al atributo
print("Mi vehiculo tiene", miVehiculo.ruedas, "ruedas")
print("Mi carrito tiene", miVehiculo.ruedas, "ruedas")
print("Mi coche tiene", miVehiculo.combustible, "de combustible")
print("Mi carrito tiene", miVehiculo.combustible, "de combustible")
print("Mi coiche tiene", miVehiculo.cilindraje, "de cilindraje")
print("Mi coche tiene", miVehiculo.puerta, "puertas")
# Forma que un objeto solicita que se ejecute un metodo
miVehiculo.desplazamiento()
obj_micarrito.desplazamiento()
# Out:
# Mi vehiculo tiene 4 ruedas
# Mi carrito tiene 4 ruedas
# Mi coche tiene Gasolina de combustible
# Mi carrito tiene Gasolina de combustible
# Mi coiche tiene 1000 de cilindraje
# Mi coche tiene 3 puertas
# El coche se está desplazando sobre 4 ruedas
# El coche se está desplazando sobre 4 ruedas

# %%
class coche():
  ruedas=4
  def desplazamiento(self):
      print("El coche se está desplazando sobre 4 ruedas")
         
      def deslazamiento(self():
        print("La moto se está desplazando sobre 2 ruedas")
miCarro=Coche()
print("--------------------Primer objeto Carro--------------------")
print("Mi coche tiene", miCarro.ruedas, "ruedas")
miCarro.desplazamiento()
print("-------------------Segundo objeto Moto---------------------")
miMoto=Moto()
print("Mi moto tiene", miMoto.ruedas, "ruedas")
miMoto.desplazamiento()

# %%
# Constructor
class Cachorro():
  # Metodo constructor
  def _init_(self, p_color, p_raza, p_nombre):
    self.color = p_color
    self.raza = p_raza
    self.nombre = p_nombre


perrito = cachorro("Marrón claro", "Golden retriever")
obj_perritodevicky = cachorro("Blanco", "shitzu")
obj_perritoElBrayan = cachorro("negro","sin identificar")
obj_GATOvaleria = cachorro("Blanco", "Angora")
obj_perroJhon = cachorro("café", "Salchicha")

print("Este es un cachorro sin dueño y la raza {} y es color {}",format(perrito.raza, perrito.color, perrito.nombre))
print("Este es un cachorro de vicky y la raza {} y es de color {}",format(obj_perritodevicky.raza, obj_perritodevicky.color))
print("Este es el perro de Bryan y la raza {} y es de color {}",format(obj_perritoElBrayan.raza, obj_perritoElBrayan.color))

# %%
class Cachorro():
  # Metodo constructor
  def _init_(self, p_color, p_raza, p_nombre):
    self.color = p_color
    self.raza = p_raza
    self.nombre = p_nombre

 # Metodo principal
 p_color = input("Color : ") 
 p_raza = input("raza : ")
 p_nombre = input("Nombre : ")

 perrito = cachorro(p_color,p_raza,p_nombre)

 print("Este es un cachorro sin dueño y la raza {} y es de color {} y se llama {}",format(perrito.raza))

# %%
class Rectangulo:
  def _init_(self,ancho,alto):
    self.ancho=ancho
    self.alto=alto
  def area(self):
    area=self.alto*self.ancho
    return area
  def perimetro(self)
      perimetro=(self.alto*2)+(self.ancho*2)
      return perimetro
  r1=Rectangulo(4,2)
  area=r1.area()
  perimetro=r1.perimetro()
  print("El area es: ", area)
  print("El perimetro es ", perimetro)
# Out:
#   File "<ipython-input-5-429304270aeb>", line 8
#     def perimetro(self)
#                        ^
# SyntaxError: invalid syntax

# %%
def m_perimetro(self):
    preimetro=(self.at_alto*2)+(self.at_ancho*2)
    return perimetro

  r1=C_RectanguloI(4,2)
  area=r1.area()
  perimetro=r1.perimetro()
  print("El area es",area)
  print("El perimetro es:",perimetro)

  p_ancho = int(input("Ancho: "))
  p_alto = int(input("Alto: "))

  obj_rect2=C_Rectangulo(p_ancho,p_alto)
  
  print("El area es", obj_rect2.m_area())
  print("El perimetro es", obj_rect2.m_perimetro())
# Out:
#   File "<tokenize>", line 5
#     r1=C_RectanguloI(4,2)
#     ^
# IndentationError: unindent does not match any outer indentation level
